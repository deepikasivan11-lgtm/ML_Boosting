# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
upload= files.upload()
# Out:
#      <input type="file" id="files-b00b9d77-fd71-4e1e-b008-776399b73a23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b00b9d77-fd71-4e1e-b008-776399b73a23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Heart_Disease_Prediction.csv')

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
df.tail()
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 265                        0         7       Absence
# 266                        0         7       Absence
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
df.shape
# Out:
# (270, 14)

# %%
df.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
#data cleaning
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
#label encoding for the column Heart Disease
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
df['Heart Disease'] = le.fit_transform(df['Heart Disease'])

# %%
#train the model
x = df.iloc[:,:-1]
y=df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=32)

# %%
#1. KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_predict = knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm_knn = confusion_matrix(y_test,y_predict)
asc_knn = accuracy_score(y_test,y_predict)
cm_knn
# Out:
# array([[21,  6],
#        [14, 13]])

# %%
asc_knn
# Out:
# 0.6296296296296297

# %%
#2. SVC

# %%
from sklearn.svm import SVC
model_svc = SVC()
model_svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predict_svc = model_svc.predict(x_test)

# %%
cm_svc = confusion_matrix(y_test,y_predict_svc)
asc_svc = accuracy_score(y_test,y_predict_svc)
cm_svc
# Out:
# array([[22,  5],
#        [18,  9]])

# %%
asc_svc
# Out:
# 0.5740740740740741

# %%
#3. logistical regression
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression()
model_lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predict = model_lr.predict(x_test)

# %%
cm_lr = confusion_matrix(y_test,y_predict)
asc_lr = accuracy_score(y_test,y_predict)
cm_lr
# Out:
# array([[23,  4],
#        [ 6, 21]])

# %%
asc_lr
# Out:
# 0.8148148148148148

# %%
#4. Naive Bayes
from sklearn.naive_bayes import GaussianNB
model_nb = GaussianNB()
model_nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_predict_nb = model_nb.predict(x_test)

# %%
cm_nb = confusion_matrix(y_test,y_predict_nb)
cm_nb
# Out:
# array([[21,  6],
#        [ 6, 21]])

# %%
asc_nb = accuracy_score(y_test,y_predict_nb)
asc_nb
# Out:
# 0.7777777777777778

# %%
#5. Decision tree
from sklearn.tree import DecisionTreeClassifier
model_dt = DecisionTreeClassifier()
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict_dt = model_dt.predict(x_test)

# %%
cm_dt = confusion_matrix(y_test,y_predict_dt)
cm_dt
# Out:
# array([[19,  8],
#        [ 9, 18]])

# %%
asc_dt = accuracy_score(y_test,y_predict_dt)
asc_dt
# Out:
# 0.6851851851851852

# %%
#6. random Forest
from sklearn.ensemble import RandomForestClassifier
mdl_rf = RandomForestClassifier()
mdl_rf.fit(x_train,y_train)
y_predict_rf = mdl_rf.predict(x_test)

# %%
cm_rf = confusion_matrix(y_test,y_predict_rf)
cm_rf
# Out:
# array([[21,  6],
#        [ 7, 20]])

# %%
asc_rf = accuracy_score(y_test,y_predict_rf)
asc_rf
# Out:
# 0.7777777777777778

# %%
from sklearn.ensemble import AdaBoostClassifier #(dt,lr,nb(gau),svc)
model_ada = AdaBoostClassifier(estimator=LogisticRegression())

# %%
model_ada.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
y_predict_ada = model_ada.predict(x_test)

# %%
asc_ada = accuracy_score(y_test,y_predict_ada)
asc_ada
# Out:
# 0.8148148148148148

# %%
cm_ada = confusion_matrix(y_test,y_predict_ada)
cm_ada
# Out:
# array([[24,  3],
#        [ 7, 20]])

# %%
#XG Booster

# %%
from xgboost import XGBClassifier
model_xgb = XGBClassifier(booster='gbtree',max_depth=3,learning_rate=0.1,n_estimators=100)
model_xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_predict_xg = model_xgb.predict(x_test)

# %%
cm_xg = confusion_matrix(y_test,y_predict_xg)
cm_xg
# Out:
# array([[20,  7],
#        [ 8, 19]])

# %%
asc_xg = accuracy_score(y_test,y_predict_xg)
asc_xg
# Out:
# 0.7222222222222222
